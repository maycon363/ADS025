# %% [markdown]
# <a href="https://colab.research.google.com/github/maycon363/ADS025/blob/master/lista6-python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Maycon Borges Pereira
# Lista 6

'''# exercicio 1

import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
data = {'matemática':[60, 58, 73, 51, 54, 75, 48, 72, 75, 83, 62, 52],#mudei os numeros
        'música':[80, 62, 70, 83, 62, 92, 79, 88, 54, 82, 64, 69]} # coloquei os temas matematica e musica
num = pd.DataFrame(data,columns = ['matemática', 'música'])
numero = num.corr()
print(numero)
'''

'''# exercicio 2 

 # resposta : 0 a 0.3 positivo ou negativo indica uma correlação desprezível.
 '''

'''# exercicio 3

import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
data = {'anos de serviço':[2, 3, 4, 5, 4, 6, 7, 8, 8, 10],
        'N de clientes':[48, 50, 56, 52, 43, 60, 62, 58, 64, 72]}
num = pd.DataFrame(data,columns = ['anos de serviço', 'N de clientes'])
numero = num.corr()
print(numero)

# resposta:
# 0.7 a 0.9 positivo ou negativo indica uma correlação forte
'''

'''#exercicio 4

import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
data = {'x':[12, 16, 18, 20, 28, 30, 40, 38, 50, 54],
        'y':[7.2, 7.4, 7.0, 6.5, 6.6, 6.7, 6.0, 5.6, 6.0, 5.5]}#coloquei os temas x e y
num = pd.DataFrame(data,columns = ['x', 'y'])# e aqui so chamei os temas x e y
numero = num.corr()
print(numero)
'''

'''#exercicio 5

#conjunto 1

import statistics
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
conjunto1 = {'x':[10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
        'y':[8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]}
num = pd.DataFrame(conjunto1,columns = ['x', 'y'])
numero1 = num.corr()
print(numero1)
print("Mediana do conjunto 'x' é:", statistics.median(conjunto1['x']))# aqui eu peguei a media do conjunto e espeficiquei com y ou x
print("Mediana do conjunto 'y' é:", statistics.median(conjunto1['y']))
print("Desvio padrão do conunto 'y' é:", statistics.stdev(conjunto1['y']))
print("Desvio padrao do cojunto 'x' é:", statistics.stdev(conjunto1['x']))

#conjunto 2

import statistics
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
conjunto2 = {'x':[10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
        'y':[9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]}
num = pd.DataFrame(conjunto2,columns = ['x', 'y'])
numero2 = num.corr()
print(numero2)
print("Mediana do conjunto 'x' é:", statistics.median(conjunto1['x']))# aqui eu peguei a media do conjunto e espeficiquei com y ou x
print("Mediana do conjunto 'y' é:", statistics.median(conjunto1['y']))
print("Desvio padrão do conunto 'y' é:", statistics.stdev(conjunto1['y']))
print("Desvio padrao do cojunto 'x' é:", statistics.stdev(conjunto1['x']))


#conjunto 3

import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import statistics
conjunto3 = {'x':[10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
        'y':[7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]}
num = pd.DataFrame(conjunto3,columns = ['x', 'y'])
numero1 = num.corr()
print(numero1)
print("Mediana do conjunto 'x' é:", statistics.median(conjunto1['x']))# aqui eu peguei a media do conjunto e espeficiquei com y ou x
print("Mediana do conjunto 'y' é:", statistics.median(conjunto1['y']))
print("Desvio padrão do conunto 'y' é:", statistics.stdev(conjunto1['y']))
print("Desvio padrao do cojunto 'x' é:", statistics.stdev(conjunto1['x']))

#conjunto 4

import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import statistics
conjunto4 = {'x':[8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8],
        'y':[6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]}
num = pd.DataFrame(conjunto4,columns = ['x', 'y'])
numero = num.corr()
print(numero)
print("Mediana do conjunto 'x' é:", statistics.median(conjunto1['x']))# aqui eu peguei a media do conjunto e espeficiquei com y ou x
print("Mediana do conjunto 'y' é:", statistics.median(conjunto1['y']))
print("Desvio padrão do conunto 'y' é:", statistics.stdev(conjunto1['y']))
print("Desvio padrao do cojunto 'x' é:", statistics.stdev(conjunto1['x']))
'''

'''# exercicio 6

import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
data = {'produtividade':[100, 102, 105, 108, 112, 120],
        'alimentação':[4, 5, 1, 3, 6, 2],# coloquei 4 temas.
        'exercicio': [1, 3, 2, 4, 5, 6,],
        'rodizio':[3, 1, 2, 6, 4,5]}# botei os 4 temas
num = pd.DataFrame(data,columns = ['produtividade', 'alimentação', 'exercicio', 'rodizio'])# mais 4 temas
numero = num.corr()#o resuldado dos num x corr
print(numero)
'''
# Out:
#                produtividade  alimentação  exercicio   rodizio
# produtividade       1.000000    -0.196822   0.925791  0.634204
# alimentação        -0.196822     1.000000   0.085714 -0.142857
# exercicio           0.925791     0.085714   1.000000  0.600000
# rodizio             0.634204    -0.142857   0.600000  1.000000
