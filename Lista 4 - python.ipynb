# %% [markdown]
# <a href="https://colab.research.google.com/github/maycon363/ADS025/blob/master/Lista%204%20-%20python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''#exercicio 1:

Triângulo = 3
Quadrado = 4
Pentagono = 5
cm = 1
op = input('Selecione: (3) Triângulo, (4) Quadrado, (5) Pentagono e (s) Sair do programa: ')
while True:
  if op == 's':
    print('Saiu do programa')
    break
  elif op == '3':
    cm += Triângulo  # exemplo: op = Quadrado + cm
    print('Triângulo!!!, medida do lado do Triângulo em cm é', cm)
    op = input('\nSelecione: (3) Triângulo, (4) Quadrado, (5) Quadrado e (s) Sair do programa: ')
  elif op == '4':
    cm += Quadrado  # exemplo: op = Quadrado + cm
    print('Quadrado!!!, medida do lado do Quadrado em cm é',cm)
    op = input('\nSelecione: (3) Triângulo, (4) Quadrado, (5) Quadrado e (s) Sair do programa: ')
  elif op == '5':
    cm += Pentagono  # exemplo: op = Quadrado + cm
    print('Pentagono!!!, medida do lado do Pentagono em cm é',cm )
    op = input('\nSelecione: (3) Triângulo, (4) Quadrado, (5) Quadrado e (s) Sair do programa: ')

# Primiero dei a condição pro usuario escolher os numeros.
# Pra n fica varios break decidir coloca a opição pra o usuario sair.
# Em todos os "elif" coloquei a opição para o usuario digita o numero novamente para ele conhecer o programa
# E se caso ele não quiser conhecer mais em algum momento do codigo é so ele coloca a letra "S". 
'''

'''#exercicio 2:

Triângulo = 3
Quadrado = 4
Pentagono = 5
cm = 1
lado = input('Selecione: (3) Triângulo, (4) Quadrado, (5) Pentagono e (s) Sair do programa: ')
while True:
  if lado == 's':
    print('Saiu do programa')
    break
  elif lado == '3':
    cm += Triângulo  # Triângulo = Quadrado + cm
    print('Triângulo!!!, medida do lado do Triângulo em cm é', cm)
    lado = input('\nSelecione: (3) Triângulo, (4) Quadrado, (5) Quadrado e (s) Sair do programa: ')
  elif lado == '4':
    cm += Quadrado  # Triângulo = Quadrado + cm
    print('Quadrado!!!, medida do lado do Quadrado em cm é',cm)
    lado = input('\nSelecione: (3) Triângulo, (4) Quadrado, (5) Quadrado e (s) Sair do programa: ')
  elif lado == '5':
    cm += Pentagono  # Triângulo = Quadrado + cm
    print('Pentagono!!!, medida do lado do Pentagono em cm é',cm )
    lado = input('\nSelecione: (3) Triângulo, (4) Quadrado, (5) Quadrado e (s) Sair do programa: ')
  elif lado < '3':
    print('NÃO É UM POLÍGONO, tente novamente!')
    lado = input('\nSelecione: (3) Triângulo, (4) Quadrado, (5) Quadrado e (s) Sair do programa: ')
  elif lado > '5':
    print('POLÍGONO NÃO IDENTIFICADO, tente novamente!')
    lado = input('\nSelecione: (3) Triângulo, (4) Quadrado, (5) Quadrado e (s) Sair do programa: ')

# coloquei dois elifs colocando a variavel 'lado' e usei para que ele verifica-se se o usuario coloca-se um numero menor que 3.
# nisso iria afirma que não era um poligono e coloquei um input novamente para ele tenta novamente.
# ja no outro elif botei para ele informa se o usuario iria coloca um numero maior que 5 fazendo o progama avisa que o poligono não foi indentificado
# coloquei também outro input pra o usuario informa novamente o  numero
'''

'''#exercicio 3:

numero1 =int(input('digite o primeiro número: '))
numero2 =int(input('Digite o segundo número: '))
numero3 =int(input('Digite o terceiro número: '))# usei 3 variaveis para o usuario digita
    
valores =[numero1,numero2,numero3] # valores e uma outra variavel que pega os resultados das 3 variaveis que o usuario digita
if (numero1 == numero2 or numero1 == numero3 or numero2 == numero3):
    print('Foi digitado numeros iguais')# se o usuario digita numeros iguais não vai funcionar
else:
    print('O maior numero é', max(valores)) # se caso o usuario digitas os 3 numeros diferente vai mostra qual foi o maior numero digitado

'''

'''#exercicio 4:

medidas = input('Selecione um desses numeros: (1), (2), (3) e para fecha o programa selecione (0): ')
while True:
  if medidas == '0':
    print('Saiu do programa')
    break
  elif medidas == '1':
    print('É um equilátero, possui os 3 lados iguais!!')
    medidas = input('\nSelecione um desses numeros:  (1), (2), (3) e para fecha o programa selecione (0): ')
  elif medidas == '2':
    print('É um Isóscele, possui 2 lados iguais.')
    medidas = input('\nSelecione um desses numeros:  (1), (2), (3) e para fecha o programa selecione (0): ')
  elif medidas == '3':
    print('É um Escaleno, possui 3 lados diferentes.')
    medidas = input('\nSelecione um desses numeros:  (1), (2), (3) e para fecha o programa selecione (0): ')
  elif medidas > '3':
    print('não encontrado, tente novamente!')
    medidas = input('\nSelecione um desses numeros:  (1), (2), (3) e para fecha o programa selecione (0): ')

# primeiro pedir para o usuario escolher um numero de 1 a 3 e dei a opição pra sair do programa.
# quando o usuario escolher um desses numero o programa mostra se é um equilatero, Isocele ou escaleno e tambem informar a quantidade de lados que ambos tem.
# se o usuario informa um numero na qual nao contem nas opições ele irar ser avisado e tera que escolhe uma das 4 opições que tem no programa.
# como variavel usei nome de 'medidas'.
# usei os elif para atribuir as condições.
'''

'''#exercicio 5:

medidas = input('informe numeros de 80 a 100: ')
while True:
  if medidas == '0':
    print('Saiu do programa')
    break
  elif medidas < '90':
    print('triângulo é Acutângulo!!!')
    print("obs: Para sair do programa coloque o numero 0")
    medidas = input('informe numeros de 80 a 100:: ')
  elif medidas == '90':
    print('triângulo é Retângulo!!!')
    print("obs: Para sair do programa coloque o numero 0")  
    medidas = input('informe numeros de 80 a 100: ')   
  elif medidas > '90':
    print('triângulo é Obtusângulo!!!')
    print("obs: Para sair do programa coloque o numero 0")
    medidas = input('informe numeros de 80 a 100: ')
#pedir pro usuario me informa para o programa um numero de 80 a 100.
#se ele digita 90 vai da um resultado.
#usei input em todas as opição para o usuario usar as 3 opções.
#em todas opições coloquei um lembrete para o usuario sai do programa.
'''

'''#exercicio 6:

soma=1
num = int(input('Insira um número inteiro maior ou igual 0: '))
for _ in range(1,num+1,2): # Exemplo --> _ = 1,3,5,7,9
  soma += _ # soma = soma + _ obs que a soma é 1 
print('A soma dos valores impares até', num, 'é', soma)

#pedir para o usuario inserir um numero e assim usei um for e um in range para pega os numeros ímpares 
# depois nas chaves o numero que o usuario coloca vai ser calculado + 1,2
# se eu digita um 3 ele vai me da o numero 5 que tambem é ímpar 
#como variavel usei a soma igual a 1 
#para imprimir eu peguei variavel 'num' que foi o numero digitado e peguei a soma que deu o resultado.
'''

'''#exercicio 7:

medidas = input('Solicitar um número entre 1 e 4: ')
while True:
  if medidas == '0':
    print('entrada inválida!!! solicitar o número novamente')
    medidas = input('\nsolicitar o número novamente entre 1 e 4: ')
  if medidas >= '5':
    print('entrada inválida!!! solicitar o número novamente')
    medidas = input('\nsolicitar o número novamente entre 1 e 4: ')
  elif medidas == '1':
    print('numero solicitado está correto!!!:',medidas)
    break
  elif medidas == '2':
    print('numero solicitado está correto!!!:',medidas)
    break
  elif medidas == '3':
    print('numero solicitado está correto!!!:',medidas)
    break
  elif medidas == '4':
    print('numero solicitado está correto!!!:',medidas)
    break

# usei "medidas" como variavel pedir que o usuario solicitar um numero de 1 a 4.
# se ele solicitar um numero maior que o 4 vai da entratada invalida e ele tera que digitar novamente.
# usei os ifs para da entrada invalida.
# e usei o break para n fica em um lup eterno.
'''

'''#exercicio 8:

numero = []#variavel
while len(numero) < 10: # Usei 10 para o input ser digitado até 10 vezes. 
    num = int(input('Digite um número [digite "0" para encerrar o programa]: '))# coloquei 0 para a opição do usuario querer sair antes
    numero.append(num)# append pega a variavel 'n' que sera tudo oque o usuario digita. 
    if num == 0: # usei a variavel 'n' se o usuario aperta 0 o programa se encarra, mostrando o resultado
      print('programa fechado.')
      break # esse codigo usei ele para da um fim ao codigo 

print ('O maior número digitado foi: ',max(numero))# Codigo 'max' ele vai pega a variavel numero.append dentro da chave tem a variavel 'n'´
                                                   # A variavel 'n' contem tudo oque o usuario digitou 
                                                   # É com o codigo 'max' ele ira pega o maior numero que o usuario digitou.

# fiquei 2 dias tentando fazer esse codigo e eu vi que tem outras maneiras tipo fazendo um lista
# exemplo valores [nun,num2,num3] tipo assim mais n conseguir usar o 0 para encerrar.
'''

'''#exercicio 9:

numero = int(input('informe um numero: '))# pedir para o usuario informa numeros
m = numero // 1 % 10# peguei o numero difidir ele por 1 tirando o modulo(%) de 10 fazendo variavel m pega o ultimo numero.
a = numero // 10 % 10 # fiz a mesma coisa com interior so que em vez de dividir ele por ele mesmo coloquei dividido por 10.
b = numero // 100 % 10# dividido por 100 pois cem = a centena 
o = numero // 1000 % 10# casa de milhar é o primeiro numero de 1 então é = 1.
print('unidade:{}'.format(m))
print('dezena:{}.format(a))
print('Centena:{}'.format(b))
print('milhar:{}'.format(o))
# Print vai mostra a casas se o é dezena e usei variaveis dentro e diferentes
'''
