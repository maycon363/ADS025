# %% [markdown]
# <a href="https://colab.research.google.com/github/maycon363/ADS025/blob/master/lista5-python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Maycon Borges Pereira
# Lista 5

'''#exercicio 1

import statistics
arr1 = ([7, 8, 9, 10, 11, 13, 13, 17])
print("Média aritmética simples é:", statistics.mean(arr1))#codigo que faz o calculo é o mean

data = ([7, 8, 9, 10, 11, 13, 13, 17])
answer = statistics.harmonic_mean(data)#codigo que faz o calculo é o mean
print("Média harmônica é:", answer)

from scipy.stats.mstats import gmean
arr1 = gmean ([7, 8, 9, 10, 11, 13, 13, 17])
print("Média geometrica é:", arr1)

arr1 = ([7, 8, 9, 10, 11, 13, 13, 17])
print('moda é:', statistics.mode(arr1))# mode e o codigo que faz o calculo

data = ([7, 8, 9, 10, 11, 13, 13, 17])
print("Variância é:", statistics.variance(data))#pra acha variancia se utiliza o codigo variance

arr1 = ([7, 8, 9, 10, 11, 13, 13, 17])
print("Desvio padrão é:", statistics.stdev(arr1))#o codigo que calcula o devio é 'stdev'
'''


'''# exercicio 2

import statistics
data = ([67, 75, 63, 72, 77, 78, 77, 80])
print("Média aritmética simples é:", statistics.mean(data))

data = ([67, 75, 63, 72, 77, 78, 77, 80])
answer = statistics.harmonic_mean(data)
print("Média harmônica é:", answer)

data = gmean ([67, 75, 63, 72, 77, 78, 77, 80])
print("Média geometrica é:", data)

data = ([67, 75, 63, 72, 77, 78, 77, 80])
print('moda é:', statistics.mode(data))#mode = calculo, data a variavel que contem os numeros

data = ([67, 75, 63, 72, 77, 78, 77, 80])
print('Mediana é:', statistics.median(data))

data = ([67, 75, 63, 72, 77, 78, 77, 80])
print("Variância é:", statistics.variance(data))

'''


'''# exercicio 3

import statistics
data = [4.0, 4.5, 5.0, 5.0, 5.5, 6.0, 6.0, 6.5, 6.5, 6.5, 
         6.5, 7.0, 7.0, 7.0, 7.0, 7.0, 7.5, 8.5, 9.0, 9.0,
         9.0, 9.5, 10.0, 10.0, 10.5, 10.0, 11.0, 12.0, 12.5, 13.0]
CV = (statistics.stdev(data)/statistics.mean(data))*100 #calculo com o codigo mean *100.
print('coeficiente da variação desse conjunto de dados é:', CV) # resuldado que deu na variavel cv e revelado em print

'''

'''# exercicio 4

import statistics# usei so uma vez pois so precisa de um para todos os codigos
data = ([12, 15, 18, 22, 17, 14, 18, 23, 29, 12])
print("media de produção é:", statistics.mean(data)) 


data = ([12, 15, 18, 22, 17, 14, 18, 23, 29, 12])
print('Mediana é:', statistics.median(data))


data = ([12, 15, 18, 22, 17, 14, 18, 23, 29, 12])
print("Desvio padrão é:", statistics.stdev(data))
'''

'''# exercicio 5

numero = []
while True: # usei o while true para fica no loop infinito e so vai sair se o usuario coloca -999
    num = int(input('digite as notas dos alunos [digite -999 pra sair do programa]: '))# coloquei 0 para a opição do usuario querer sair antes
    numero.append(num)
    if num == -999:# assim que o usuario digita -999 o programa é fechado mostrando media, moda, a variancia...
      print('programa fechado.')
      break 
    if num > 10:5# se o usuario digita uma nota acima de 10 o programa da erro fazendo ele digita novamente
      print ('nota incorreta digite a nota de 1 a 10 [digite -999 pra sair do programa]:')

import statistics
num = ([67, 75, 63, 72, 77, 78, 77, 80])
print("Média aritmética simples é:", statistics.mean(num))

num = ([67, 75, 63, 72, 77, 78, 77, 80])
answer = statistics.harmonic_mean(num)
print("Média harmônica é:", answer)

num = gmean ([67, 75, 63, 72, 77, 78, 77, 80])
print("Média geometrica é:", num)

num = ([67, 75, 63, 72, 77, 78, 77, 80])
print('moda é:', statistics.mode(num))

num = ([67, 75, 63, 72, 77, 78, 77, 80])
print("Variância é:", statistics.variance(num))

num = ([7, 8, 9, 10, 11, 13, 13, 17])
print("Desvio padrão é:", statistics.stdev(num))

CV = (statistics.stdev(num)/statistics.mean(num))*100
print('coeficiente da variação desse conjunto de dados é:', CV)
'''

'''
#exercicio 6 

numero = 0
num = int(input('digite as notas dos alunos: '))
num1 = int(input('digite as notas dos alunos: '))
num2 = int(input('digite as notas dos alunos: '))

numero = (num * 3 + num1 * 4 + num2 * 3 ) / 10 #OBS: basicamente ess calculo fazemos usando para calcular nossa notas
print('nota do aluno:',numero)
'''
